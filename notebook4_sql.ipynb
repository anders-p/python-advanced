# %%
import pyodbc
import time

server = "sqllabschris.database.windows.net"
database = "demo"
username = "Lumify"
password = "Password123"

connection_string = (
    "DRIVER={SQL Server};"
    f"SERVER={server};"
    f"DATABASE={database};"
    f"UID={username};"
    f"PWD={password};"
    "Encrypt=yes;"
    "TrustServerCertificate=no;"
    "Connection Timeout=30;"
)

conn = pyodbc.connect(connection_string)

print("Success")

time.sleep(30)

conn.close()
# Out:
# Success
